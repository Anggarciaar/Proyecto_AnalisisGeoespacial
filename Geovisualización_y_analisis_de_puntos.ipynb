# %% [markdown]
# <a href="https://colab.research.google.com/github/Anggarciaar/Proyecto_AnalisisGeoespacial/blob/main/Geovisualizaci%C3%B3n_y_analisis_de_puntos.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount("/content/drive", force_remount=True)
# Out:
# Mounted at /content/drive

# %%
import os
base_dir="/content/drive/MyDrive/DATA_ProyectoAG"
print(base_dir)
# Out:
# /content/drive/MyDrive/DATA_ProyectoAG

# %% [markdown]
# ## **Librerias**

# %%
#Install the necessary packages
# !pip install seaborn
# !pip install contextily
# !pip install pysal
# !pip install osmnx
# !pip install numpy==1.23.5
# !pip install geopandas
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: seaborn in /usr/local/lib/python3.10/dist-packages (0.12.2)
# Requirement already satisfied: numpy!=1.24.0,>=1.17 in /usr/local/lib/python3.10/dist-packages (from seaborn) (1.25.0)
# Requirement already satisfied: pandas>=0.25 in /usr/local/lib/python3.10/dist-packages (from seaborn) (1.5.3)
# Requirement already satisfied: matplotlib!=3.6.1,>=3.1 in /usr/local/lib/python3.10/dist-packages (from seaborn) (3.7.1)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (1.1.0)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (4.40.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (23.1)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (9.5.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (3.1.0)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=0.25->seaborn) (2022.7.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.7->matplotlib!=3.6.1,>=3.1->seaborn) (1.16.0)
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: contextily in /usr/local/lib/python3.10/dist-packages (1.3.0)
# Requirement already satisfied: geopy in /usr/local/lib/python3.10/dist-packages (from contextily) (2.3.0)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (from contextily) (3.7.1)
# Requirement already satisfied: mercantile in /usr/local/lib/python3.10/dist-packages (from contextily) (1.2.1)
# Requirement already satisfied: pillow in /usr/local/lib/python3.10/dist-packages (from contextily) (9.5.0)
# Requirement already satisfied: rasterio in /usr/local/lib/python3.10/dist-packages (from contextily) (1.3.7)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from contextily) (2.31.0)
# Requirement already satisfied: joblib in /usr/local/lib/python3.10/dist-packages (from contextily) (1.2.0)
# Requirement already satisfied: xyzservices in /usr/local/lib/python3.10/dist-packages (from contextily) (2023.5.0)
# Requirement already satisfied: geographiclib<3,>=1.52 in /usr/local/lib/python3.10/dist-packages (from geopy->contextily) (2.0)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->contextily) (1.1.0)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib->contextily) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->contextily) (4.40.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->contextily) (1.4.4)
# Requirement already satisfied: numpy>=1.20 in /usr/local/lib/python3.10/dist-packages (from matplotlib->contextily) (1.25.0)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->contextily) (23.1)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->contextily) (3.1.0)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib->contextily) (2.8.2)
# Requirement already satisfied: click>=3.0 in /usr/local/lib/python3.10/dist-packages (from mercantile->contextily) (8.1.3)
# Requirement already satisfied: affine in /usr/local/lib/python3.10/dist-packages (from rasterio->contextily) (2.4.0)
# Requirement already satisfied: attrs in /usr/local/lib/python3.10/dist-packages (from rasterio->contextily) (23.1.0)
# Requirement already satisfied: certifi in /usr/local/lib/python3.10/dist-packages (from rasterio->contextily) (2023.5.7)
# Requirement already satisfied: cligj>=0.5 in /usr/local/lib/python3.10/dist-packages (from rasterio->contextily) (0.7.2)
# Requirement already satisfied: snuggs>=1.4.1 in /usr/local/lib/python3.10/dist-packages (from rasterio->contextily) (1.4.7)
# Requirement already satisfied: click-plugins in /usr/local/lib/python3.10/dist-packages (from rasterio->contextily) (1.1.1)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from rasterio->contextily) (67.7.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->contextily) (2.0.12)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->contextily) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->contextily) (1.26.16)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.7->matplotlib->contextily) (1.16.0)
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: pysal in /usr/local/lib/python3.10/dist-packages (23.1)
# Requirement already satisfied: libpysal>=4.7.0 in /usr/local/lib/python3.10/dist-packages (from pysal) (4.7.0)
# Requirement already satisfied: access>=1.1.8 in /usr/local/lib/python3.10/dist-packages (from pysal) (1.1.9)
# Requirement already satisfied: esda>=2.4.1 in /usr/local/lib/python3.10/dist-packages (from pysal) (2.4.3)
# Requirement already satisfied: giddy>=2.3.3 in /usr/local/lib/python3.10/dist-packages (from pysal) (2.3.4)
# Requirement already satisfied: inequality>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from pysal) (1.0.0)
# Requirement already satisfied: pointpats>=2.2.0 in /usr/local/lib/python3.10/dist-packages (from pysal) (2.3.0)
# Requirement already satisfied: segregation>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from pysal) (2.4.2)
# Requirement already satisfied: spaghetti>=1.7.2 in /usr/local/lib/python3.10/dist-packages (from pysal) (1.7.4)
# Requirement already satisfied: mgwr>=2.1.2 in /usr/local/lib/python3.10/dist-packages (from pysal) (2.1.2)
# Requirement already satisfied: momepy>=0.5.4 in /usr/local/lib/python3.10/dist-packages (from pysal) (0.6.0)
# Requirement already satisfied: spglm>=1.0.8 in /usr/local/lib/python3.10/dist-packages (from pysal) (1.0.8)
# Requirement already satisfied: spint>=1.0.7 in /usr/local/lib/python3.10/dist-packages (from pysal) (1.0.7)
# Requirement already satisfied: spreg>=1.3.0 in /usr/local/lib/python3.10/dist-packages (from pysal) (1.3.2)
# Requirement already satisfied: spvcm>=0.3.0 in /usr/local/lib/python3.10/dist-packages (from pysal) (0.3.0)
# Requirement already satisfied: tobler>=0.8.2 in /usr/local/lib/python3.10/dist-packages (from pysal) (0.10)
# Requirement already satisfied: mapclassify>=2.5.0 in /usr/local/lib/python3.10/dist-packages (from pysal) (2.5.0)
# Requirement already satisfied: splot>=1.1.5.post1 in /usr/local/lib/python3.10/dist-packages (from pysal) (1.1.5.post1)
# Requirement already satisfied: spopt>=0.5.0 in /usr/local/lib/python3.10/dist-packages (from pysal) (0.5.0)
# Requirement already satisfied: geopandas in /usr/local/lib/python3.10/dist-packages (from access>=1.1.8->pysal) (0.13.2)
# Requirement already satisfied: numpy>=1.3 in /usr/local/lib/python3.10/dist-packages (from access>=1.1.8->pysal) (1.25.0)
# Requirement already satisfied: pandas>=0.23.4 in /usr/local/lib/python3.10/dist-packages (from access>=1.1.8->pysal) (1.5.3)
# Requirement already satisfied: requests>=2 in /usr/local/lib/python3.10/dist-packages (from access>=1.1.8->pysal) (2.31.0)
# Requirement already satisfied: scipy>=0.11 in /usr/local/lib/python3.10/dist-packages (from esda>=2.4.1->pysal) (1.10.1)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.10/dist-packages (from esda>=2.4.1->pysal) (1.2.2)
# Requirement already satisfied: quantecon>=0.4.7 in /usr/local/lib/python3.10/dist-packages (from giddy>=2.3.3->pysal) (0.7.1)
# Requirement already satisfied: platformdirs in /usr/local/lib/python3.10/dist-packages (from libpysal>=4.7.0->pysal) (3.7.0)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.10/dist-packages (from libpysal>=4.7.0->pysal) (4.11.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from libpysal>=4.7.0->pysal) (3.1.2)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from libpysal>=4.7.0->pysal) (23.1)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from mapclassify>=2.5.0->pysal) (3.1)
# Requirement already satisfied: shapely>=2 in /usr/local/lib/python3.10/dist-packages (from momepy>=0.5.4->pysal) (2.0.1)
# Requirement already satisfied: tqdm>=4.27.0 in /usr/local/lib/python3.10/dist-packages (from momepy>=0.5.4->pysal) (4.65.0)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (from pointpats>=2.2.0->pysal) (3.7.1)
# Requirement already satisfied: deprecation in /usr/local/lib/python3.10/dist-packages (from segregation>=2.3.1->pysal) (2.1.0)
# Requirement already satisfied: joblib in /usr/local/lib/python3.10/dist-packages (from segregation>=2.3.1->pysal) (1.2.0)
# Requirement already satisfied: seaborn in /usr/local/lib/python3.10/dist-packages (from segregation>=2.3.1->pysal) (0.12.2)
# Requirement already satisfied: numba in /usr/local/lib/python3.10/dist-packages (from segregation>=2.3.1->pysal) (0.56.4)
# Requirement already satisfied: pyproj>=3 in /usr/local/lib/python3.10/dist-packages (from segregation>=2.3.1->pysal) (3.6.0)
# Requirement already satisfied: rtree in /usr/local/lib/python3.10/dist-packages (from spaghetti>=1.7.2->pysal) (1.0.1)
# Requirement already satisfied: pulp in /usr/local/lib/python3.10/dist-packages (from spopt>=0.5.0->pysal) (2.7.0)
# Requirement already satisfied: rasterio in /usr/local/lib/python3.10/dist-packages (from tobler>=0.8.2->pysal) (1.3.7)
# Requirement already satisfied: statsmodels in /usr/local/lib/python3.10/dist-packages (from tobler>=0.8.2->pysal) (0.13.5)
# Requirement already satisfied: rasterstats in /usr/local/lib/python3.10/dist-packages (from tobler>=0.8.2->pysal) (0.19.0)
# Requirement already satisfied: fiona>=1.8.19 in /usr/local/lib/python3.10/dist-packages (from geopandas->access>=1.1.8->pysal) (1.9.4.post1)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=0.23.4->access>=1.1.8->pysal) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=0.23.4->access>=1.1.8->pysal) (2022.7.1)
# Requirement already satisfied: certifi in /usr/local/lib/python3.10/dist-packages (from pyproj>=3->segregation>=2.3.1->pysal) (2023.5.7)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from quantecon>=0.4.7->giddy>=2.3.3->pysal) (1.11.1)
# Requirement already satisfied: llvmlite<0.40,>=0.39.0dev0 in /usr/local/lib/python3.10/dist-packages (from numba->segregation>=2.3.1->pysal) (0.39.1)
# Collecting numpy>=1.3 (from access>=1.1.8->pysal)
#   Using cached numpy-1.23.5-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (17.1 MB)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from numba->segregation>=2.3.1->pysal) (67.7.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests>=2->access>=1.1.8->pysal) (2.0.12)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests>=2->access>=1.1.8->pysal) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests>=2->access>=1.1.8->pysal) (1.26.16)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn->esda>=2.4.1->pysal) (3.1.0)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.10/dist-packages (from beautifulsoup4->libpysal>=4.7.0->pysal) (2.4.1)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->libpysal>=4.7.0->pysal) (2.1.3)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->pointpats>=2.2.0->pysal) (1.1.0)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib->pointpats>=2.2.0->pysal) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->pointpats>=2.2.0->pysal) (4.40.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->pointpats>=2.2.0->pysal) (1.4.4)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->pointpats>=2.2.0->pysal) (9.5.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->pointpats>=2.2.0->pysal) (3.1.0)
# Requirement already satisfied: affine in /usr/local/lib/python3.10/dist-packages (from rasterio->tobler>=0.8.2->pysal) (2.4.0)
# Requirement already satisfied: attrs in /usr/local/lib/python3.10/dist-packages (from rasterio->tobler>=0.8.2->pysal) (23.1.0)
# Requirement already satisfied: click>=4.0 in /usr/local/lib/python3.10/dist-packages (from rasterio->tobler>=0.8.2->pysal) (8.1.3)
# Requirement already satisfied: cligj>=0.5 in /usr/local/lib/python3.10/dist-packages (from rasterio->tobler>=0.8.2->pysal) (0.7.2)
# Requirement already satisfied: snuggs>=1.4.1 in /usr/local/lib/python3.10/dist-packages (from rasterio->tobler>=0.8.2->pysal) (1.4.7)
# Requirement already satisfied: click-plugins in /usr/local/lib/python3.10/dist-packages (from rasterio->tobler>=0.8.2->pysal) (1.1.1)
# Requirement already satisfied: simplejson in /usr/local/lib/python3.10/dist-packages (from rasterstats->tobler>=0.8.2->pysal) (3.19.1)
# Requirement already satisfied: patsy>=0.5.2 in /usr/local/lib/python3.10/dist-packages (from statsmodels->tobler>=0.8.2->pysal) (0.5.3)
# Requirement already satisfied: six in /usr/local/lib/python3.10/dist-packages (from fiona>=1.8.19->geopandas->access>=1.1.8->pysal) (1.16.0)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->quantecon>=0.4.7->giddy>=2.3.3->pysal) (1.3.0)
# Installing collected packages: numpy
#   Attempting uninstall: numpy
#     Found existing installation: numpy 1.25.0
#     Uninstalling numpy-1.25.0:
#       Successfully uninstalled numpy-1.25.0
# Successfully installed numpy-1.23.5
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: osmnx in /usr/local/lib/python3.10/dist-packages (1.4.0)
# Requirement already satisfied: geopandas>=0.12 in /usr/local/lib/python3.10/dist-packages (from osmnx) (0.13.2)
# Requirement already satisfied: networkx>=2.5 in /usr/local/lib/python3.10/dist-packages (from osmnx) (3.1)
# Requirement already satisfied: numpy>=1.20 in /usr/local/lib/python3.10/dist-packages (from osmnx) (1.23.5)
# Requirement already satisfied: pandas>=1.1 in /usr/local/lib/python3.10/dist-packages (from osmnx) (1.5.3)
# Requirement already satisfied: requests>=2.25 in /usr/local/lib/python3.10/dist-packages (from osmnx) (2.31.0)
# Requirement already satisfied: shapely>=2.0 in /usr/local/lib/python3.10/dist-packages (from osmnx) (2.0.1)
# Requirement already satisfied: fiona>=1.8.19 in /usr/local/lib/python3.10/dist-packages (from geopandas>=0.12->osmnx) (1.9.4.post1)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from geopandas>=0.12->osmnx) (23.1)
# Requirement already satisfied: pyproj>=3.0.1 in /usr/local/lib/python3.10/dist-packages (from geopandas>=0.12->osmnx) (3.6.0)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.1->osmnx) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.1->osmnx) (2022.7.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests>=2.25->osmnx) (2.0.12)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests>=2.25->osmnx) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests>=2.25->osmnx) (1.26.16)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests>=2.25->osmnx) (2023.5.7)
# Requirement already satisfied: attrs>=19.2.0 in /usr/local/lib/python3.10/dist-packages (from fiona>=1.8.19->geopandas>=0.12->osmnx) (23.1.0)
# Requirement already satisfied: click~=8.0 in /usr/local/lib/python3.10/dist-packages (from fiona>=1.8.19->geopandas>=0.12->osmnx) (8.1.3)
# Requirement already satisfied: click-plugins>=1.0 in /usr/local/lib/python3.10/dist-packages (from fiona>=1.8.19->geopandas>=0.12->osmnx) (1.1.1)
# Requirement already satisfied: cligj>=0.5 in /usr/local/lib/python3.10/dist-packages (from fiona>=1.8.19->geopandas>=0.12->osmnx) (0.7.2)
# Requirement already satisfied: six in /usr/local/lib/python3.10/dist-packages (from fiona>=1.8.19->geopandas>=0.12->osmnx) (1.16.0)
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: numpy==1.23.5 in /usr/local/lib/python3.10/dist-packages (1.23.5)
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: geopandas in /usr/local/lib/python3.10/dist-packages (0.13.2)
# Requirement already satisfied: fiona>=1.8.19 in /usr/local/lib/python3.10/dist-packages (from geopandas) (1.9.4.post1)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from geopandas) (23.1)
# Requirement already satisfied: pandas>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from geopandas) (1.5.3)
# Requirement already satisfied: pyproj>=3.0.1 in /usr/local/lib/python3.10/dist-packages (from geopandas) (3.6.0)
# Requirement already satisfied: shapely>=1.7.1 in /usr/local/lib/python3.10/dist-packages (from geopandas) (2.0.1)
# Requirement already satisfied: attrs>=19.2.0 in /usr/local/lib/python3.10/dist-packages (from fiona>=1.8.19->geopandas) (23.1.0)
# Requirement already satisfied: certifi in /usr/local/lib/python3.10/dist-packages (from fiona>=1.8.19->geopandas) (2023.5.7)
# Requirement already satisfied: click~=8.0 in /usr/local/lib/python3.10/dist-packages (from fiona>=1.8.19->geopandas) (8.1.3)
# Requirement already satisfied: click-plugins>=1.0 in /usr/local/lib/python3.10/dist-packages (from fiona>=1.8.19->geopandas) (1.1.1)
# Requirement already satisfied: cligj>=0.5 in /usr/local/lib/python3.10/dist-packages (from fiona>=1.8.19->geopandas) (0.7.2)
# Requirement already satisfied: six in /usr/local/lib/python3.10/dist-packages (from fiona>=1.8.19->geopandas) (1.16.0)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.1.0->geopandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.1.0->geopandas) (2022.7.1)
# Requirement already satisfied: numpy>=1.21.0 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.1.0->geopandas) (1.23.5)

# %%
pip install numpy --upgrade
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (1.23.5)
# Collecting numpy
#   Using cached numpy-1.25.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (17.6 MB)
# Installing collected packages: numpy
#   Attempting uninstall: numpy
#     Found existing installation: numpy 1.23.5
#     Uninstalling numpy-1.23.5:
#       Successfully uninstalled numpy-1.23.5
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# numba 0.56.4 requires numpy<1.24,>=1.18, but you have numpy 1.25.0 which is incompatible.
# tensorflow 2.12.0 requires numpy<1.24,>=1.22, but you have numpy 1.25.0 which is incompatible.
# Successfully installed numpy-1.25.0

# %%
#Import the necessary libraries
import numpy as np
import pandas as pd
import geopandas as gpd

import osmnx as ox

import pysal

import seaborn as sbn
import contextily as ctx
import matplotlib.pyplot as plt

# %%
import matplotlib.pyplot as plt
import rasterio

# %% [markdown]
# ## ***CARGA DE DATOS***
#
# # **1.Emisiones por departamento.**

# %%
# !pip install pandas
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (1.5.3)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.10/dist-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas) (2022.7.1)
# Requirement already satisfied: numpy>=1.21.0 in /usr/local/lib/python3.10/dist-packages (from pandas) (1.25.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.1->pandas) (1.16.0)

# %%
# !pip install geopandas
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: geopandas in /usr/local/lib/python3.10/dist-packages (0.13.2)
# Requirement already satisfied: fiona>=1.8.19 in /usr/local/lib/python3.10/dist-packages (from geopandas) (1.9.4.post1)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from geopandas) (23.1)
# Requirement already satisfied: pandas>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from geopandas) (1.5.3)
# Requirement already satisfied: pyproj>=3.0.1 in /usr/local/lib/python3.10/dist-packages (from geopandas) (3.6.0)
# Requirement already satisfied: shapely>=1.7.1 in /usr/local/lib/python3.10/dist-packages (from geopandas) (2.0.1)
# Requirement already satisfied: attrs>=19.2.0 in /usr/local/lib/python3.10/dist-packages (from fiona>=1.8.19->geopandas) (23.1.0)
# Requirement already satisfied: certifi in /usr/local/lib/python3.10/dist-packages (from fiona>=1.8.19->geopandas) (2023.5.7)
# Requirement already satisfied: click~=8.0 in /usr/local/lib/python3.10/dist-packages (from fiona>=1.8.19->geopandas) (8.1.3)
# Requirement already satisfied: click-plugins>=1.0 in /usr/local/lib/python3.10/dist-packages (from fiona>=1.8.19->geopandas) (1.1.1)
# Requirement already satisfied: cligj>=0.5 in /usr/local/lib/python3.10/dist-packages (from fiona>=1.8.19->geopandas) (0.7.2)
# Requirement already satisfied: six in /usr/local/lib/python3.10/dist-packages (from fiona>=1.8.19->geopandas) (1.16.0)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.1.0->geopandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.1.0->geopandas) (2022.7.1)
# Requirement already satisfied: numpy>=1.21.0 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.1.0->geopandas) (1.25.0)

# %%
import geopandas as gpd
import pandas as pd

# %%
import pandas as pd
import numpy as np

# %%
# !pip install geopandas
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: geopandas in /usr/local/lib/python3.10/dist-packages (0.13.2)
# Requirement already satisfied: fiona>=1.8.19 in /usr/local/lib/python3.10/dist-packages (from geopandas) (1.9.4.post1)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from geopandas) (23.1)
# Requirement already satisfied: pandas>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from geopandas) (1.5.3)
# Requirement already satisfied: pyproj>=3.0.1 in /usr/local/lib/python3.10/dist-packages (from geopandas) (3.6.0)
# Requirement already satisfied: shapely>=1.7.1 in /usr/local/lib/python3.10/dist-packages (from geopandas) (2.0.1)
# Requirement already satisfied: attrs>=19.2.0 in /usr/local/lib/python3.10/dist-packages (from fiona>=1.8.19->geopandas) (23.1.0)
# Requirement already satisfied: certifi in /usr/local/lib/python3.10/dist-packages (from fiona>=1.8.19->geopandas) (2023.5.7)
# Requirement already satisfied: click~=8.0 in /usr/local/lib/python3.10/dist-packages (from fiona>=1.8.19->geopandas) (8.1.3)
# Requirement already satisfied: click-plugins>=1.0 in /usr/local/lib/python3.10/dist-packages (from fiona>=1.8.19->geopandas) (1.1.1)
# Requirement already satisfied: cligj>=0.5 in /usr/local/lib/python3.10/dist-packages (from fiona>=1.8.19->geopandas) (0.7.2)
# Requirement already satisfied: six in /usr/local/lib/python3.10/dist-packages (from fiona>=1.8.19->geopandas) (1.16.0)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.1.0->geopandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.1.0->geopandas) (2022.7.1)
# Requirement already satisfied: numpy>=1.21.0 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.1.0->geopandas) (1.25.0)

# %%
import geopandas as gpd

# %%
Departamentos = gpd.read_file("/content/drive/MyDrive/DATA_ProyectoAG/Emisiones_Departamento/EA_TCNCC_EN_100K_2016.shp")

# %%
Departamentos.info()
# Out:
# <class 'geopandas.geodataframe.GeoDataFrame'>
# RangeIndex: 33 entries, 0 to 32
# Data columns (total 20 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   cod_depto   33 non-null     object
#  1   departamen  33 non-null     object
#  2   ems_nts_GE  33 non-null     float64
#  3   IPPC_energ  33 non-null     float64
#  4   IPPC_IPPU   33 non-null     float64
#  5   IPPC_AFOLU  33 non-null     float64
#  6   IPPC_resid  33 non-null     float64
#  7   sctr_fores  33 non-null     float64
#  8   sctr_indus  33 non-null     float64
#  9   sctr_agrop  33 non-null     float64
#  10  sctr_trans  33 non-null     float64
#  11  sctr_minas  33 non-null     float64
#  12  sctr_sanea  33 non-null     float64
#  13  sctr_resid  33 non-null     float64
#  14  sctr_comer  33 non-null     float64
#  15  area_ha     33 non-null     float64
#  16  SHAPE_Leng  33 non-null     float64
#  17  SHAPE_Area  33 non-null     float64
#  18  RULEID      33 non-null     int64
#  19  geometry    33 non-null     geometry
# dtypes: float64(16), geometry(1), int64(1), object(2)
# memory usage: 5.3+ KB

# %%
Departamentos.head(32)
# Out:
#    cod_depto                                 departamen  ems_nts_GE  \
# 0         91                                   AMAZONAS    0.513058
# 1         05                                  ANTIOQUIA   12.946967
# 2         81                                     ARAUCA    3.462820
# 3         08                                  ATLÁNTICO    7.341928
# 4         13                                    BOLÍVAR    7.311540
# 5         15                                     BOYACÁ    9.998332
# 6         17                                     CALDAS   -0.533074
# 7         18                                    CAQUETÁ   18.605941
# 8         85                                   CASANARE    9.443649
# 9         19                                      CAUCA    0.926403
# 10        20                                      CESAR    4.516532
# 11        27                                      CHOCÓ    2.482121
# 12        23                                    CÓRDOBA    5.788089
# 13        25                               CUNDINAMARCA   11.170681
# 14        94                                    GUAINÍA    1.082786
# 15        95                                   GUAVIARE   10.219472
# 16        41                                      HUILA   -0.665385
# 17        44                                 LA GUAJIRA    5.156127
# 18        47                                  MAGDALENA    3.374750
# 19        50                                       META   17.306738
# 20        52                                     NARIÑO    6.079243
# 21        54                         NORTE DE SANTANDER    4.704809
# 22        86                                   PUTUMAYO    6.345306
# 23        63                                    QUINDÍO   -0.166552
# 24        66                                  RISARALDA   -0.798737
# 25        88  ARCHIPIÉLAGO DE SAN ANDRÉS. PROVIDENCIA Y    0.303271
# 26        68                                  SANTANDER   10.570665
# 27        70                                      SUCRE    2.774736
# 28        73                                     TOLIMA    1.515687
# 29        76                            VALLE DEL CAUCA   12.099754
# 30        97                                     VAUPÉS    1.513483
# 31        99                                    VICHADA   -0.779771
#
#      IPPC_energ    IPPC_IPPU    IPPC_AFOLU   IPPC_resid    sctr_fores  \
# 0     83.027695     0.786040    422.302502     6.942034    404.831433
# 1   8793.464113  1350.703025   1236.964593  1565.835611   1444.536348
# 2    244.463869     4.979072   3156.942814    56.434010   1694.365789
# 3   5506.572866   674.963450    497.446684   662.945224    157.551756
# 4   2877.350050  1130.339006   2824.149233   479.701379   1436.953784
# 5   5536.980714  1468.516781   2756.365356   236.469266   1200.349930
# 6    956.273150    39.084520  -1830.123625   301.691872    117.717776
# 7    279.808564     5.664958  18242.003860    78.463313  16305.834248
# 8   5496.804939     7.691213   3822.836208   116.316823    503.974694
# 9   1344.910817    26.237913   -749.209666   304.463452   1544.010173
# 10  1747.591576    15.316213   2490.895921   262.728626     74.338520
# 11   378.013751     5.589892   2038.309367    60.207825    560.474711
# 12   967.382232   845.023165   3711.264857   264.419063    540.230472
# 13  5765.962908   437.874998   4162.983178   803.860108   1509.299333
# 14    26.008515     0.565156   1044.232026    11.980045   1029.329360
# 15    54.417542     0.975418  10150.537153    13.542196   9775.979374
# 16  1263.056018    71.301668  -2238.028005   238.285750   1452.224947
# 17  3686.306356     9.864021   1307.186275   152.770676    827.235420
# 18   577.759650    18.271014   2457.090709   321.628390   -227.280840
# 19  2776.598977    19.574484  14176.832972   333.731254  10642.367146
# 20  1191.154396    26.876754   4609.622427   251.589807   2186.613585
# 21  1786.858911   153.541700   2408.390548   356.017897   1419.400821
# 22   370.464838     4.441439   5900.513856    69.886002   4788.209028
# 23   424.532973    12.850657   -789.533108   185.597792    -39.922751
# 24   739.575802    23.297910  -1888.374164   326.763915     65.622148
# 25   239.556655     2.072026     35.463062    26.179477     33.907860
# 26  5295.670281   257.282598   4260.243069   757.469010   3069.038235
# 27   658.337369   287.029809   1673.622197   155.746433    347.860076
# 28  1978.957423  1047.116820  -1912.213229   401.825624   1370.515083
# 29  8079.445906   623.661704    800.338069  2596.307984   -121.842296
# 30    12.673521     0.571200   1497.940317     2.298109   1491.370548
# 31    39.654853     0.674991   -828.199350     8.098716  -1348.198127
#
#      sctr_indus   sctr_agrop   sctr_trans  sctr_minas   sctr_sanea  \
# 0      0.158128    19.845740    25.099117         0.0     6.942034
# 1   5247.494024    18.338103  3880.540778         0.0  1031.445886
# 2      0.925160  1500.916424    39.772105         0.0    56.406601
# 3   1629.713659   362.912386  1149.086209         0.0   486.964824
# 4   1527.318930  1445.815313  1117.092574         0.0   410.296608
# 5   3096.423317  1677.745295   836.305070         0.0   211.914586
# 6    349.585154 -1900.852581   498.331265         0.0   220.905235
# 7      6.431997  1955.139095   195.049999         0.0    77.204294
# 8     15.188720  3373.298929   445.638812         0.0   108.783672
# 9    832.741703 -2250.432836   341.502439         0.0   183.639232
# 10    79.200095  2472.586271   700.991610         0.0   248.176079
# 11     2.775234  1495.532491   279.164101         0.0    60.207825
# 12   954.272608  3248.191738   560.284175         0.0   252.459106
# 13  2824.149040  2846.043917  2199.205958         0.0   350.843543
# 14     0.098847    15.372111     6.297375         0.0    11.980045
# 15     0.295746   376.116009    48.992163         0.0    13.542196
# 16   170.348718 -3621.892479   561.425222         0.0   163.005626
# 17     3.011542   494.724614   261.509882         0.0   152.764565
# 18    78.898121  2744.888359   353.674133         0.0   262.706748
# 19   148.306366  3637.024660   838.778448         0.0   242.444808
# 20    24.768025  2488.776171   844.678017         0.0   239.835964
# 21   547.886717  1038.863884   396.911117         0.0   351.332899
# 22     1.692997  1118.420057   122.383011         0.0    69.584484
# 23    38.457530  -715.649456   304.271322         0.0   159.991654
# 24   128.359761 -1916.245744   503.452970         0.0   269.031925
# 25     0.395005     2.128661    78.423654         0.0    26.158322
# 26   618.711540  1310.671320  1318.275386         0.0   421.295356
# 27   398.422553  1356.428268   250.240601         0.0   152.160819
# 28  1577.670053 -3194.474494   930.429478         0.0   351.421169
# 29  6412.458292  1063.788521  2991.768009         0.0  1042.550230
# 30     0.075464     6.849938     3.238696         0.0     2.298109
# 31     0.227524   521.369385    17.066119         0.0     8.098716
#
#     sctr_resid  sctr_comer       area_ha  SHAPE_Leng  SHAPE_Area  RULEID  \
# 0     6.288620    0.434545  1.094979e+07   25.596483    8.877566       2
# 1   599.901859  247.149863  6.296306e+06   21.109882    5.147846       6
# 2    21.701719    1.572121  2.382024e+06    8.987916    1.941630       3
# 3   235.333159  114.212659  3.321987e+05    2.529379    0.274446       4
# 4   191.124196   42.344982  2.669793e+06   14.975281    2.193822       4
# 5   324.576061   43.155498  2.315195e+06   15.454153    1.889526       5
# 6   128.098961   29.622734  7.438898e+05    6.521573    0.606614       1
# 7    60.128600    2.940459  9.010823e+06   21.306751    7.318908       6
# 8    25.665734   10.991966  4.436293e+06   11.975771    3.612520       5
# 9   238.287917   12.989494  3.124940e+06   13.769394    2.534944       2
# 10  101.109953   33.165268  2.256217e+06   11.716212    1.857944       3
# 11   66.521336    2.447122  4.819097e+06   20.186320    3.926481       2
# 12  140.456858   20.976267  2.500524e+06    8.862750    2.050866       3
# 13  283.248909  120.238336  2.236730e+06   12.739556    1.823371       6
# 14    1.874033    0.271352  7.127470e+06   21.110287    5.746827       2
# 15    2.673454    0.480794  5.557912e+06   19.390892    4.511781       5
# 16  147.031493   20.048046  1.813680e+06   10.165785    1.473825       1
# 17   75.245282   17.751809  2.061697e+06   10.657273    1.706707       3
# 18  119.538729   24.315345  2.313767e+06    9.984070    1.909411       3
# 19   93.638421   30.573528  8.555124e+06   18.088147    6.957530       6
# 20  260.515548   13.476734  3.148647e+06   12.111602    2.547579       3
# 21  119.039604   13.782719  2.183506e+06   10.492117    1.790547       3
# 22    9.985814    2.080923  2.597704e+06   12.667164    2.108025       3
# 23   65.329280   18.785205  1.932173e+05    2.511448    0.157310       1
# 24  109.613334   37.472099  3.560349e+05    4.661057    0.290082       1
# 25   60.717622    1.337980  4.971505e+03    0.652403    0.004074       2
# 26  208.490319   99.818424  3.055841e+06   11.631733    2.498856       5
# 27   71.412082   11.001882  1.067971e+06    7.824228    0.878023       2
# 28  187.371444   30.917666  2.414873e+06    9.339397    1.965786       2
# 29  484.082904  148.599096  2.065480e+06   12.222911    1.678614       6
# 30    1.876251    0.274473  5.329041e+06   20.107380    4.313120       2
# 31    1.900023    0.344821  1.000907e+07   17.255195    8.102704       1
#
#                                              geometry
# 0   POLYGON ((-69.43300 -1.06967, -69.43309 -1.070...
# 1   POLYGON ((-74.82915 8.19958, -74.82858 8.19945...
# 2   POLYGON ((-69.42759 6.10748, -69.42839 6.10742...
# 3   POLYGON ((-74.85257 11.10548, -74.84393 11.072...
# 4   POLYGON ((-75.22236 10.79653, -75.22224 10.796...
# 5   POLYGON ((-72.04767 7.03830, -72.04681 7.03917...
# 6   POLYGON ((-74.66030 5.76716, -74.65912 5.76428...
# 7   POLYGON ((-73.66003 1.61206, -73.66003 1.61206...
# 8   POLYGON ((-72.33887 6.34575, -72.34114 6.34496...
# 9   POLYGON ((-76.05335 3.21896, -76.05293 3.21847...
# 10  POLYGON ((-72.90075 10.43611, -72.90059 10.435...
# 11  POLYGON ((-76.98033 8.25525, -76.98017 8.24840...
# 12  POLYGON ((-75.69984 9.41196, -75.70219 9.38478...
# 13  POLYGON ((-73.05261 4.73574, -73.07369 4.59549...
# 14  POLYGON ((-69.84570 1.71393, -69.84572 1.71392...
# 15  POLYGON ((-71.07753 2.88223, -71.07689 2.88248...
# 16  POLYGON ((-74.44132 3.72937, -74.44028 3.72970...
# 17  POLYGON ((-72.90075 10.43611, -72.90076 10.436...
# 18  POLYGON ((-73.56995 11.25931, -73.56987 11.258...
# 19  POLYGON ((-71.07753 2.88223, -71.07843 2.88291...
# 20  POLYGON ((-77.92833 2.64040, -77.92691 2.63673...
# 21  POLYGON ((-72.04767 7.03830, -72.04807 7.03790...
# 22  POLYGON ((-76.08482 1.05726, -76.08388 1.05694...
# 23  POLYGON ((-75.38860 4.71626, -75.38847 4.71618...
# 24  POLYGON ((-75.86740 5.48817, -75.86725 5.48555...
# 25  MULTIPOLYGON (((-81.37115 13.39473, -81.37113 ...
# 26  POLYGON ((-73.63368 7.74945, -73.63367 7.74945...
# 27  POLYGON ((-74.78500 8.27587, -74.78610 8.27730...
# 28  POLYGON ((-74.73332 5.28540, -74.73249 5.28367...
# 29  POLYGON ((-75.71291 4.71462, -75.70834 4.67835...
# 30  POLYGON ((-70.10960 2.08005, -70.10966 2.07993...
# 31  POLYGON ((-67.70960 4.04740, -67.71029 4.04597...

# %%
Departamentos.plot();

# %%
import matplotlib.pyplot as plt
fig, ax = plt.subplots(figsize=(12,10))
Departamentos.plot(column='ems_nts_GE', ax=ax);

# %% [markdown]
# # **2.Cuencas sedimentarias de Colombia.**

# %%
import pandas as pd

# %%
# !pip install geopandas
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: geopandas in /usr/local/lib/python3.10/dist-packages (0.13.2)
# Requirement already satisfied: fiona>=1.8.19 in /usr/local/lib/python3.10/dist-packages (from geopandas) (1.9.4.post1)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from geopandas) (23.1)
# Requirement already satisfied: pandas>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from geopandas) (1.5.3)
# Requirement already satisfied: pyproj>=3.0.1 in /usr/local/lib/python3.10/dist-packages (from geopandas) (3.6.0)
# Requirement already satisfied: shapely>=1.7.1 in /usr/local/lib/python3.10/dist-packages (from geopandas) (2.0.1)
# Requirement already satisfied: attrs>=19.2.0 in /usr/local/lib/python3.10/dist-packages (from fiona>=1.8.19->geopandas) (23.1.0)
# Requirement already satisfied: certifi in /usr/local/lib/python3.10/dist-packages (from fiona>=1.8.19->geopandas) (2023.5.7)
# Requirement already satisfied: click~=8.0 in /usr/local/lib/python3.10/dist-packages (from fiona>=1.8.19->geopandas) (8.1.3)
# Requirement already satisfied: click-plugins>=1.0 in /usr/local/lib/python3.10/dist-packages (from fiona>=1.8.19->geopandas) (1.1.1)
# Requirement already satisfied: cligj>=0.5 in /usr/local/lib/python3.10/dist-packages (from fiona>=1.8.19->geopandas) (0.7.2)
# Requirement already satisfied: six in /usr/local/lib/python3.10/dist-packages (from fiona>=1.8.19->geopandas) (1.16.0)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.1.0->geopandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.1.0->geopandas) (2022.7.1)
# Requirement already satisfied: numpy>=1.21.0 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.1.0->geopandas) (1.25.0)

# %%
#Data de división de cuencas sedimentarias en Colombia
Cuencas = gpd.read_file("/content/drive/MyDrive/DATA_ProyectoAG/Cuencas_Sedimentarias/CUENCAS_AJUSTADAS_2010.shp")

# %%
SSJ = gpd.read_file("/content/drive/MyDrive/DATA_ProyectoAG/Datos creados/Emisiones SSJ.shp")

# %%
print(SSJ)
# Out:
#    DPTO_CCDGO MPIO_CCDGO              MPIO_CNMBR                 MPIO_CRSLC  \
# 0          13        620          SAN CRISTÃBAL  ORD 36 DE FEBRERO DE 1996
# 1          13        647          SAN ESTANISLAO                       1936
# 2          13        654             SAN JACINTO                       1899
# 3          13        657     SAN JUAN NEPOMUCENO                       1780
# 4          13        673          SANTA CATALINA                       1772
# ..        ...        ...                     ...                        ...
# 81         70        713              SAN ONOFRE                       1899
# 82         70        820       SANTIAGO DE TOLÃ                       1899
# 83         70        823  SAN JOSÃ DE TOLUVIEJO                       1899
# 84         70        473                  MORROA                       1855
# 85        NaN        NaN                     NaN                        NaN
#
#      MPIO_NAREA MPIO_CCNCT  MPIO_NANO DPTO_CNMBR  SHAPE_AREA  SHAPE_LEN  \
# 0     42.268805      13620     2020.0   BOLÃVAR    0.003488   0.301725
# 1    211.639257      13647     2020.0   BOLÃVAR    0.017465   0.715870
# 2    442.915991      13654     2020.0   BOLÃVAR    0.036494   1.349255
# 3    631.224741      13657     2020.0   BOLÃVAR    0.052031   1.663275
# 4    172.774220      13673     2020.0   BOLÃVAR    0.014270   1.051040
# ..          ...        ...        ...        ...         ...        ...
# 81  1035.078993      70713     2020.0      SUCRE    0.085255   2.080517
# 82   302.516692      70820     2020.0      SUCRE    0.024896   0.980402
# 83   285.015891      70823     2020.0      SUCRE    0.023455   1.209799
# 84   170.014897      70473     2020.0      SUCRE    0.013988   0.676134
# 85          NaN        NaN        NaN  Antioquia         NaN        NaN
#
#         COD  Emisiones  Emisiones2  \
# 0   13620.0    21.0211     15.3356
# 1   13647.0    21.0211     15.3356
# 2   13654.0   135.6200     98.9394
# 3   13657.0   135.6200     98.9394
# 4   13673.0    29.8364     21.7667
# ..      ...        ...         ...
# 81  70713.0    17.6358     14.9426
# 82  70820.0    45.2200     38.3143
# 83  70823.0   198.0640    167.8170
# 84  70473.0    26.2276     22.2223
# 85      NaN     6.6600      6.0000
#
#                                              geometry
# 0   POLYGON ((890666.098 1643146.065, 890671.003 1...
# 1   POLYGON ((880654.703 1647646.051, 880666.623 1...
# 2   POLYGON ((900789.356 1571557.732, 900781.993 1...
# 3   POLYGON ((907091.226 1586133.049, 905527.797 1...
# 4   POLYGON ((868820.287 1676820.290, 869053.500 1...
# ..                                                ...
# 81  POLYGON ((835117.412 1558216.706, 834842.871 1...
# 82  POLYGON ((832035.306 1539338.510, 832178.779 1...
# 83  POLYGON ((852573.214 1557790.464, 852584.714 1...
# 84  POLYGON ((864704.594 1539823.875, 864747.456 1...
# 85  POLYGON ((743010.562 1388151.218, 742934.578 1...
#
# [86 rows x 14 columns]

# %%
Cuencas.info()
# Out:
# <class 'geopandas.geodataframe.GeoDataFrame'>
# RangeIndex: 24 entries, 0 to 23
# Data columns (total 17 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   FID_CUENCA  24 non-null     int64
#  1   NOMBRE      24 non-null     object
#  2   AREA        24 non-null     float64
#  3   NMG         24 non-null     object
#  4   AÑO         24 non-null     int64
#  5   TIPO        23 non-null     object
#  6   TIPO_2      14 non-null     object
#  7   LOWYTF      24 non-null     int64
#  8   BASEYTF     24 non-null     int64
#  9   HIGHYTF     24 non-null     int64
#  10  R_PROBADAS  24 non-null     int64
#  11  R_PROBABLE  24 non-null     int64
#  12  R_POSIBLES  24 non-null     int64
#  13  FID_LIMITE  24 non-null     int64
#  14  ObjectID    24 non-null     int64
#  15  EntID       24 non-null     int64
#  16  geometry    24 non-null     geometry
# dtypes: float64(1), geometry(1), int64(11), object(4)
# memory usage: 3.3+ KB

# %%
#Tabla de datos
Cuencas.head(24)
# Out:
#     FID_CUENCA                        NOMBRE          AREA       NMG   AÑO  \
# 0            3              GUAJIRA OFFSHORE  5.274678e+06   GUA OFF  2007
# 1            4                 SINU OFFSHORE  2.947888e+06   SIN OFF  2007
# 2            7                     LOS CAYOS  1.445157e+07       CAY  2007
# 3           10                      COLOMBIA  2.566933e+07       COL  2007
# 4           11  PACIFICO PROFUNDO COLOMBIANO  2.698517e+07   PAC PRF  2007
# 5           15                CHOCO OFFSHORE  3.746078e+06   CHO OFF  2007
# 6           16               TUMACO OFFSHORE  3.232512e+06   TUM OFF  2007
# 7            0                         AMAGA  2.824929e+05       AMA  2007
# 8            1           AREA NO PROSPECTIVA  3.282873e+07       ANP  2007
# 9            2               CAGUAN-PUTUMAYO  1.099493e+07   CAG PUT  2007
# 10           5                     CATATUMBO  7.720632e+05       CAT  2007
# 11           6                   CAUCA PATIA  1.282331e+06   CAU PAT  2007
# 12           8               CESAR RANCHERIA  1.168550e+06   CES RAN  2007
# 13           9                         CHOCO  3.891897e+06       CHO  2007
# 14          12           CORDILLERA ORIENTAL  7.174581e+06       COR  2007
# 15          13                       GUAJIRA  1.385609e+06       GUA  2007
# 16          14             LLANOS ORIENTALES  2.257066e+07       LLA  2007
# 17          18                        TUMACO  2.510154e+06       TUM  2007
# 18          20  VALLE INFERIOR DEL MAGDALENA  3.801740e+06       VIM  2007
# 19          21     VALLE MEDIO DEL MAGDALENA  3.294942e+06       VMM  2007
# 20          22  VALLE SUPERIOR DEL MAGDALENA  2.151284e+06       VSM  2007
# 21          23               VAUPES-AMAZONAS  1.545700e+07  VAU AMAZ  2007
# 22          17              SINU-SAN JACINTO  3.974779e+06    SIN SJ  2007
# 23          19                         URABA  9.465012e+05       URA  2007
#
#         TIPO                                        TIPO_2  LOWYTF  BASEYTF  \
# 0   OFFSHORE                        TRANSTENSIONAL  MARGIN     226      350
# 1   OFFSHORE                            ACCRETIONARY PRISM       0       50
# 2   OFFSHORE                                           NaN       0       10
# 3   OFFSHORE                                           NaN       0       50
# 4   OFFSHORE                                           NaN       0        0
# 5   OFFSHORE                                           NaN       0       50
# 6   OFFSHORE                                           NaN       0       50
# 7   FRONTERA                                           NaN       0        0
# 8        NaN                                           NaN       0        0
# 9     MADURA                                      FORELAND     255      300
# 10    MADURA                                      FORELAND       0      200
# 11  FRONTERA                             COLLISION RELATED       0       10
# 12  FRONTERA                                 INTRAMOUNTAIN      17       44
# 13  FRONTERA                                     FORE ARC?       0       50
# 14  FRONTERA                   INVERTED GRABEN / FOLD BELT      16      450
# 15  FRONTERA                        TRANSTENSIONAL  MARGIN      30      100
# 16    MADURA                             CENOZOIC FORELAND       0      500
# 17  FRONTERA                                           NaN       0       50
# 18    MADURA                                TRANSTENSIONAL     312      450
# 19    MADURA           POLYHISTORY RIFT TO BROKEN FORELAND       0      600
# 20    MADURA  POLYHISTORY RIFT SHOULDER TO BROKEN FORELAND       0      550
# 21  FRONTERA                                           NaN       0        5
# 22  FRONTERA                            ACCRETIONARY PRISM       0       50
# 23  FRONTERA                                           NaN       0       10
#
#     HIGHYTF  R_PROBADAS  R_PROBABLE  R_POSIBLES  FID_LIMITE  ObjectID  EntID  \
# 0      1929           0           0           0          -1         0      0
# 1       784           0           0           0          -1         0      0
# 2        11           0           0           0          -1         0      0
# 3        50           0           0           0          -1         0      0
# 4         0           0           0           0          -1         0      0
# 5       798           0           0           0          -1         0      0
# 6       618           0           0           0          -1         0      0
# 7         0           0           0           0           0         1      2
# 8         0           0           0           0           0         1      2
# 9       955          57         128          51           0         1      2
# 10      199          26         151          28           0         1      2
# 11       50           0           0           0           0         1      2
# 12       49           0           0           0           0         1      2
# 13      978           0           0           0           0         1      2
# 14      574         168          19           7           0         1      2
# 15      185         386          73         785           0         1      2
# 16     1463         712        1493        2463           0         1      2
# 17      688           0           0           0           0         1      2
# 18      510          73          53        1079           0         1      2
# 19     1014         320         645         276           0         1      2
# 20      569         135         224         319           0         1      2
# 21     1240           0           0           0           0         1      2
# 22     1011           0           0         262           0         1      2
# 23      199           0           0           0          -1         0      0
#
#                                              geometry
# 0   POLYGON Z ((1322674.118 1871541.442 0.000, 132...
# 1   MULTIPOLYGON Z (((953422.143 1752659.478 0.000...
# 2   POLYGON Z ((443213.279 2287211.920 0.000, 4429...
# 3   POLYGON Z ((1060075.900 1904657.708 0.000, 102...
# 4   POLYGON Z ((292094.635 656338.951 0.000, -2248...
# 5   POLYGON Z ((579790.670 1291077.684 0.000, 5799...
# 6   POLYGON Z ((467989.621 655792.087 0.000, 29209...
# 7   POLYGON Z ((806478.855 1183302.583 0.000, 8057...
# 8   MULTIPOLYGON Z (((1003508.374 1746889.414 0.00...
# 9   POLYGON Z ((1042217.870 741297.143 0.000, 1048...
# 10  POLYGON Z ((1118019.312 1518993.402 0.000, 111...
# 11  POLYGON Z ((805405.031 1052125.845 0.000, 8039...
# 12  POLYGON Z ((1151578.844 1725538.537 0.000, 115...
# 13  POLYGON Z ((655212.046 1368919.742 0.000, 6553...
# 14  POLYGON Z ((1176852.058 1337805.521 0.000, 117...
# 15  POLYGON Z ((1262240.182 1870575.139 0.000, 126...
# 16  POLYGON Z ((1375562.742 1277436.060 0.000, 137...
# 17  POLYGON Z ((701378.257 930061.263 0.000, 69674...
# 18  POLYGON Z ((1016992.175 1597182.465 0.000, 101...
# 19  POLYGON Z ((1048134.345 1506075.666 0.000, 104...
# 20  POLYGON Z ((879973.598 798711.212 0.000, 87526...
# 21  MULTIPOLYGON Z (((1419379.360 609617.750 0.000...
# 22  POLYGON Z ((917048.979 1719084.167 0.000, 9171...
# 23  POLYGON Z ((680413.182 1471139.138 0.000, 6907...

# %%
#Mapa de las cuencas
import matplotlib.pyplot as plt
fig, ax = plt.subplots(figsize=(12,10))
Cuencas.plot(column='NOMBRE', ax=ax);

# %%
SSJ = gpd.read_file("/content/drive/MyDrive/DATA_ProyectoAG/Datos creados/Sinu_SanJacinto.shp")

# %%
SSJ.head(4)
# Out:
#    FID_CUENCA            NOMBRE          AREA     NMG   AÑO      TIPO  \
# 0          17  SINU-SAN JACINTO  3.974779e+06  SIN SJ  2007  FRONTERA
#
#                TIPO_2  LOWYTF  BASEYTF  HIGHYTF  R_PROBADAS  R_PROBABLE  \
# 0  ACCRETIONARY PRISM       0       50     1011           0           0
#
#    R_POSIBLES  FID_LIMITE  ObjectID  EntID  \
# 0         262           0         1      2
#
#                                             geometry
# 0  POLYGON Z ((917048.979 1719084.167 0.000, 9171...

# %%
#Cuenca Sinu San Jacinto
SSJ.plot()
# Out:
# <Axes: >

# %% [markdown]
# # **3.Emisiones por ciudad**

# %%
import pandas as pd

# %%
# !pip install geopandas
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: geopandas in /usr/local/lib/python3.10/dist-packages (0.13.2)
# Requirement already satisfied: fiona>=1.8.19 in /usr/local/lib/python3.10/dist-packages (from geopandas) (1.9.4.post1)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from geopandas) (23.1)
# Requirement already satisfied: pandas>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from geopandas) (1.5.3)
# Requirement already satisfied: pyproj>=3.0.1 in /usr/local/lib/python3.10/dist-packages (from geopandas) (3.6.0)
# Requirement already satisfied: shapely>=1.7.1 in /usr/local/lib/python3.10/dist-packages (from geopandas) (2.0.1)
# Requirement already satisfied: attrs>=19.2.0 in /usr/local/lib/python3.10/dist-packages (from fiona>=1.8.19->geopandas) (23.1.0)
# Requirement already satisfied: certifi in /usr/local/lib/python3.10/dist-packages (from fiona>=1.8.19->geopandas) (2023.5.7)
# Requirement already satisfied: click~=8.0 in /usr/local/lib/python3.10/dist-packages (from fiona>=1.8.19->geopandas) (8.1.3)
# Requirement already satisfied: click-plugins>=1.0 in /usr/local/lib/python3.10/dist-packages (from fiona>=1.8.19->geopandas) (1.1.1)
# Requirement already satisfied: cligj>=0.5 in /usr/local/lib/python3.10/dist-packages (from fiona>=1.8.19->geopandas) (0.7.2)
# Requirement already satisfied: six in /usr/local/lib/python3.10/dist-packages (from fiona>=1.8.19->geopandas) (1.16.0)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.1.0->geopandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.1.0->geopandas) (2022.7.1)
# Requirement already satisfied: numpy>=1.21.0 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.1.0->geopandas) (1.25.0)

# %%
#Data de emisiones por ciudad
Ciudades = gpd.read_file("/content/drive/MyDrive/DATA_ProyectoAG/Datos creados/Emisiones SSJ.shp")

# %%
#Maxima y Minima emisión
max_emisiones = Ciudades['Emisiones'].max()
min_emisiones = Ciudades['Emisiones'].min()

print(max_emisiones)
print(min_emisiones)
# Out:
# 4171.81
# 6.66

# %%
#Ciudades con mayores emisiones
fila_max = Ciudades.loc[Ciudades['Emisiones'] == max_emisiones]

print(fila_max)
# Out:
#    DPTO_CCDGO MPIO_CCDGO    MPIO_CNMBR  \
# 39         08        001  BARRANQUILLA
# 46         08        433       MALAMBO
# 58         08        758       SOLEDAD
#
#                                            MPIO_CRSLC  MPIO_NAREA MPIO_CCNCT  \
# 39  Ordenanza 30 del 5 de Mayo de 1913 Ley 44 del ...  154.202079      08001
# 46               Ordenanza 24 del 24 de Abril de 1912   97.942337      08433
# 58                                               1813   59.358357      08758
#
#     MPIO_NANO  DPTO_CNMBR  SHAPE_AREA  SHAPE_LEN     COD  Emisiones  \
# 39     2020.0  ATLÃNTICO    0.012753   0.814371  8001.0    4171.81
# 46     2020.0  ATLÃNTICO    0.008097   0.499109  8433.0    4171.81
# 58     2020.0  ATLÃNTICO    0.004908   0.420027  8758.0    4171.81
#
#     Emisiones2                                           geometry
# 39     2507.02  MULTIPOLYGON (((913349.678 1713760.426, 913426...
# 46     2507.02  POLYGON ((918604.160 1696305.952, 918613.208 1...
# 58     2507.02  POLYGON ((925318.566 1702142.495, 925340.342 1...

# %%
Ciudades.info()
# Out:
# <class 'geopandas.geodataframe.GeoDataFrame'>
# RangeIndex: 86 entries, 0 to 85
# Data columns (total 14 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   DPTO_CCDGO  85 non-null     object
#  1   MPIO_CCDGO  85 non-null     object
#  2   MPIO_CNMBR  85 non-null     object
#  3   MPIO_CRSLC  85 non-null     object
#  4   MPIO_NAREA  85 non-null     float64
#  5   MPIO_CCNCT  85 non-null     object
#  6   MPIO_NANO   85 non-null     float64
#  7   DPTO_CNMBR  86 non-null     object
#  8   SHAPE_AREA  85 non-null     float64
#  9   SHAPE_LEN   85 non-null     float64
#  10  COD         85 non-null     float64
#  11  Emisiones   86 non-null     float64
#  12  Emisiones2  86 non-null     float64
#  13  geometry    86 non-null     geometry
# dtypes: float64(7), geometry(1), object(6)
# memory usage: 9.5+ KB

# %%
Ciudades.head(2)
# Out:
#   DPTO_CCDGO MPIO_CCDGO      MPIO_CNMBR                 MPIO_CRSLC  \
# 0         13        620  SAN CRISTÃBAL  ORD 36 DE FEBRERO DE 1996
# 1         13        647  SAN ESTANISLAO                       1936
#
#    MPIO_NAREA MPIO_CCNCT  MPIO_NANO DPTO_CNMBR  SHAPE_AREA  SHAPE_LEN  \
# 0   42.268805      13620     2020.0   BOLÃVAR    0.003488   0.301725
# 1  211.639257      13647     2020.0   BOLÃVAR    0.017465   0.715870
#
#        COD  Emisiones  Emisiones2  \
# 0  13620.0    21.0211     15.3356
# 1  13647.0    21.0211     15.3356
#
#                                             geometry
# 0  POLYGON ((890666.098 1643146.065, 890671.003 1...
# 1  POLYGON ((880654.703 1647646.051, 880666.623 1...

# %%
Ordenadoporemisiones=Ciudades.sort_values('Emisiones', ascending=False)

# %%
Ordenadoporemisiones.head(5)
# Out:
#    DPTO_CCDGO MPIO_CCDGO           MPIO_CNMBR  \
# 39         08        001         BARRANQUILLA
# 58         08        758              SOLEDAD
# 46         08        433              MALAMBO
# 70         13        442       MARÃA LA BAJA
# 62         13        001  CARTAGENA DE INDIAS
#
#                                            MPIO_CRSLC  MPIO_NAREA MPIO_CCNCT  \
# 39  Ordenanza 30 del 5 de Mayo de 1913 Ley 44 del ...  154.202079      08001
# 58                                               1813   59.358357      08758
# 46               Ordenanza 24 del 24 de Abril de 1912   97.942337      08433
# 70        Ley 119 del 14 de Septiembretiembre de 1936  559.917843      13442
# 62                                               1599  597.681012      13001
#
#     MPIO_NANO  DPTO_CNMBR  SHAPE_AREA  SHAPE_LEN      COD  Emisiones  \
# 39     2020.0  ATLÃNTICO    0.012753   0.814371   8001.0    4171.81
# 58     2020.0  ATLÃNTICO    0.004908   0.420027   8758.0    4171.81
# 46     2020.0  ATLÃNTICO    0.008097   0.499109   8433.0    4171.81
# 70     2020.0    BOLÃVAR    0.046146   1.404783  13442.0    1869.52
# 62     2020.0    BOLÃVAR    0.049325   4.239567  13001.0    1869.52
#
#     Emisiones2                                           geometry
# 39     2507.02  MULTIPOLYGON (((913349.678 1713760.426, 913426...
# 58     2507.02  POLYGON ((925318.566 1702142.495, 925340.342 1...
# 46     2507.02  POLYGON ((918604.160 1696305.952, 918613.208 1...
# 70     1363.88  POLYGON ((865212.388 1608065.176, 865235.068 1...
# 62     1363.88  MULTIPOLYGON (((840756.832 1617267.966, 840830...

# %%
primeros_items = Ordenadoporemisiones.head(6)

# %%
#Las 6 ciudades con mayores emisiones dentro de la cuenca Sinu San Jacinto
primeros_items.head()
# Out:
#    DPTO_CCDGO MPIO_CCDGO           MPIO_CNMBR  \
# 39         08        001         BARRANQUILLA
# 58         08        758              SOLEDAD
# 46         08        433              MALAMBO
# 70         13        442       MARÃA LA BAJA
# 62         13        001  CARTAGENA DE INDIAS
#
#                                            MPIO_CRSLC  MPIO_NAREA MPIO_CCNCT  \
# 39  Ordenanza 30 del 5 de Mayo de 1913 Ley 44 del ...  154.202079      08001
# 58                                               1813   59.358357      08758
# 46               Ordenanza 24 del 24 de Abril de 1912   97.942337      08433
# 70        Ley 119 del 14 de Septiembretiembre de 1936  559.917843      13442
# 62                                               1599  597.681012      13001
#
#     MPIO_NANO  DPTO_CNMBR  SHAPE_AREA  SHAPE_LEN      COD  Emisiones  \
# 39     2020.0  ATLÃNTICO    0.012753   0.814371   8001.0    4171.81
# 58     2020.0  ATLÃNTICO    0.004908   0.420027   8758.0    4171.81
# 46     2020.0  ATLÃNTICO    0.008097   0.499109   8433.0    4171.81
# 70     2020.0    BOLÃVAR    0.046146   1.404783  13442.0    1869.52
# 62     2020.0    BOLÃVAR    0.049325   4.239567  13001.0    1869.52
#
#     Emisiones2                                           geometry
# 39     2507.02  MULTIPOLYGON (((913349.678 1713760.426, 913426...
# 58     2507.02  POLYGON ((925318.566 1702142.495, 925340.342 1...
# 46     2507.02  POLYGON ((918604.160 1696305.952, 918613.208 1...
# 70     1363.88  POLYGON ((865212.388 1608065.176, 865235.068 1...
# 62     1363.88  MULTIPOLYGON (((840756.832 1617267.966, 840830...

# %%
data_nuevo = Ordenadoporemisiones.loc[:, ["MPIO_CNMBR", "Emisiones"]]

# %%
data_nuevo.head(6)
# Out:
#                MPIO_CNMBR  Emisiones
# 39           BARRANQUILLA    4171.81
# 58                SOLEDAD    4171.81
# 46                MALAMBO    4171.81
# 70         MARÃA LA BAJA    1869.52
# 62    CARTAGENA DE INDIAS    1869.52
# 67  EL CARMEN DE BOLÃVAR    1869.52

# %%
import pandas as pd

# %%
import matplotlib.pyplot as plt

# %%
#Histograma de Emisiones por ciudad
import seaborn as sns
Tabla = sns.distplot(Ciudades['Emisiones'], kde=False)
# Out:
# <ipython-input-126-e3d7b21ea6a6>:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   Tabla = sns.distplot(Ciudades['Emisiones'], kde=False)

# %%
sns.boxplot(Ciudades['Emisiones']);

# %%
import statsmodels.api as sm
import pylab as py
import numpy as np

data_points = np.random.normal(0, 1, 100)

sm.qqplot(data_points, line ='45')
py.show()

# %%
sm.qqplot(Ciudades['Emisiones'], line ='45')
py.show()

# %%
data_points
# Out:
# array([ 0.14381673, -0.22461368,  1.04029917,  1.36600174, -0.29282952,
#        -0.68259397, -1.21566444,  0.66175079, -0.02170693, -1.36524936,
#        -0.14219847,  0.42517343, -0.62881191,  1.27747683, -0.19597045,
#         0.85035833,  1.68383661,  2.20457063, -0.47584914, -0.67734444,
#         0.38257256,  0.67704947,  1.05500201, -1.265876  ,  2.01709001,
#        -0.529478  ,  0.79915343, -0.15656056,  0.79995249, -0.08575014,
#         2.13059008, -0.26488516,  1.76006495, -0.77018093, -0.7743805 ,
#         0.46711402,  1.32965291,  0.60316183, -0.65175282,  0.19584013,
#         0.23910037, -1.06775118, -0.33368502, -0.73724565, -0.61277824,
#        -1.71973978, -0.49134382,  0.19447612, -0.82455163, -1.75812965,
#         1.58272382, -1.56777343,  0.38694616, -0.78329037, -0.239177  ,
#        -0.46292103, -0.6604679 ,  0.25637126, -1.12595476,  0.6907244 ,
#        -0.19615565, -0.49458249, -0.52184553, -0.20706133, -0.97493637,
#         1.1240763 , -0.2496987 , -2.40345996,  1.38489533,  0.95099281,
#        -0.82634543, -0.82864237,  0.70450393, -0.05524382, -1.54122413,
#         0.95531677,  0.71403905, -0.21249568,  0.86129249, -1.00200398,
#         0.34644124, -0.83688908, -0.24680667,  0.57874518,  1.28045557,
#         2.24556789, -1.91896292, -1.38306637,  0.70684609,  0.22971753,
#         0.7145505 , -0.86127574,  1.12915545,  0.25336951, -0.19423188,
#        -1.46869942, -0.36378345,  1.15015848, -0.47816876, -1.74403696])

# %%
import matplotlib.pyplot as plt
fig, ax = plt.subplots(figsize=(12,10))
Ciudades.plot(column='Emisiones', ax=ax);

# %%
#Mapa de emisiones por ciudades
vmin, vmax = 6.66, 4171.81
fig, ax = plt.subplots(1, figsize=(10, 6))
Ciudades.plot(column="Emisiones", cmap='Blues', linewidth=0.8, ax=ax, edgecolor='0.8')
ax.axis('off')
ax.set_title('Emisiones por ciudad', \
              fontdict={'fontsize': '25',
                        'fontweight' : '3'})
ax.annotate('Source: INGEI)',
           xy=(0.2, .08), xycoords='figure fraction',
           horizontalalignment='left', verticalalignment='top',
           fontsize=10, color='#555555')

# Create colorbar as a legend
sm = plt.cm.ScalarMappable(cmap='Blues', norm=plt.Normalize(vmin=vmin, vmax=vmax))
sm._A = []
cbar = fig.colorbar(sm)


fig.savefig('/content/drive/MyDrive/DATA_ProyectoAG/Datos creados/MapadeEmisiones.png', dpi=300)
# Out:
# <ipython-input-132-a971bfcdbf0d>:17: MatplotlibDeprecationWarning: Unable to determine Axes to steal space for Colorbar. Using gca(), but will raise in the future. Either provide the *cax* argument to use as the Axes for the Colorbar, provide the *ax* argument to steal space from it, or add *mappable* to an Axes.
#   cbar = fig.colorbar(sm)

# %%
import matplotlib.pyplot as plt

# %%
#centroide de las ciudades con mayores emisiones
Centro=primeros_items.centroid
Centro.head(6)
# Out:
# 39    POINT (918139.810 1705885.892)
# 58    POINT (923372.659 1698024.823)
# 46    POINT (920323.005 1691547.579)
# 70    POINT (861142.569 1595235.094)
# 62    POINT (848811.538 1649315.113)
# 67    POINT (877121.713 1566798.039)
# dtype: geometry

# %%
import pandas as pd

# Crear un DataFrame a partir de la columna "Centro"
df_centro = pd.DataFrame(Centro.geometry)

# Imprimir los primeros registros del DataFrame "df_centro"
print(df_centro.head())
# Out:
#                                  0
# 39  POINT (918139.810 1705885.892)
# 58  POINT (923372.659 1698024.823)
# 46  POINT (920323.005 1691547.579)
# 70  POINT (861142.569 1595235.094)
# 62  POINT (848811.538 1649315.113)

# %%
from shapely.geometry import Point
geometria=[Point(918139.810,1705885.892), Point(923372.659,1698024.823), Point(920323.005,1691547.579),Point(861142.569,1595235.094),Point(848811.538,1649315.113),Point(877121.713,1566798.039)]

# %%
gdf = gpd.GeoDataFrame(df_centro, geometry=geometria)

# %%
Centro.plot()
# Out:
# <Axes: >

# %%
cents =primeros_items.centroid
cents.head()
# Out:
# 39    POINT (918139.810 1705885.892)
# 58    POINT (923372.659 1698024.823)
# 46    POINT (920323.005 1691547.579)
# 70    POINT (861142.569 1595235.094)
# 62    POINT (848811.538 1649315.113)
# dtype: geometry

# %%
fig, ax = plt.subplots()
SSJ.plot(ax=ax, facecolor='none', edgecolor='black')
puntos_dentro = cents.within(SSJ.geometry.iloc[0])  # Filtrar puntos dentro del polígono
cents[puntos_dentro].plot(ax=ax, color='red', markersize=5)
plt.show()


fig.savefig('/content/drive/MyDrive/DATA_ProyectoAG/Datos creados/centroides.png', dpi=300)

# %%
pip install descarteslabs[complete]
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: descarteslabs[complete] in /usr/local/lib/python3.10/dist-packages (2.0.1)
# Requirement already satisfied: Pillow>=9.2.0 in /usr/local/lib/python3.10/dist-packages (from descarteslabs[complete]) (9.5.0)
# Requirement already satisfied: affine>=2.2.2 in /usr/local/lib/python3.10/dist-packages (from descarteslabs[complete]) (2.4.0)
# Requirement already satisfied: blosc>=1.10.6 in /usr/local/lib/python3.10/dist-packages (from descarteslabs[complete]) (1.11.1)
# Requirement already satisfied: cachetools>=3.1.1 in /usr/local/lib/python3.10/dist-packages (from descarteslabs[complete]) (5.3.1)
# Requirement already satisfied: dill>=0.3.6 in /usr/local/lib/python3.10/dist-packages (from descarteslabs[complete]) (0.3.6)
# Requirement already satisfied: dynaconf>=3.1.11 in /usr/local/lib/python3.10/dist-packages (from descarteslabs[complete]) (3.1.12)
# Requirement already satisfied: geojson>=2.5.0 in /usr/local/lib/python3.10/dist-packages (from descarteslabs[complete]) (3.0.1)
# Requirement already satisfied: imagecodecs>=2021.5.20 in /usr/local/lib/python3.10/dist-packages (from descarteslabs[complete]) (2023.3.16)
# Requirement already satisfied: lazy-object-proxy>=1.7.1 in /usr/local/lib/python3.10/dist-packages (from descarteslabs[complete]) (1.9.0)
# Requirement already satisfied: mercantile>=1.1.3 in /usr/local/lib/python3.10/dist-packages (from descarteslabs[complete]) (1.2.1)
# Requirement already satisfied: pytz>=2021.1 in /usr/local/lib/python3.10/dist-packages (from descarteslabs[complete]) (2022.7.1)
# Requirement already satisfied: requests<3,>=2.28.1 in /usr/local/lib/python3.10/dist-packages (from descarteslabs[complete]) (2.31.0)
# Requirement already satisfied: setuptools>=65.6.3 in /usr/local/lib/python3.10/dist-packages (from descarteslabs[complete]) (67.7.2)
# Requirement already satisfied: shapely>=1.8.1 in /usr/local/lib/python3.10/dist-packages (from descarteslabs[complete]) (2.0.1)
# Requirement already satisfied: strenum>=0.4.8 in /usr/local/lib/python3.10/dist-packages (from descarteslabs[complete]) (0.4.10)
# Requirement already satisfied: tifffile==2021.4.8 in /usr/local/lib/python3.10/dist-packages (from descarteslabs[complete]) (2021.4.8)
# Requirement already satisfied: tqdm>=4.32.1 in /usr/local/lib/python3.10/dist-packages (from descarteslabs[complete]) (4.65.0)
# Requirement already satisfied: urllib3<2,>=1.26.12 in /usr/local/lib/python3.10/dist-packages (from descarteslabs[complete]) (1.26.16)
# Requirement already satisfied: numpy>=1.21.6 in /usr/local/lib/python3.10/dist-packages (from descarteslabs[complete]) (1.25.0)
# Requirement already satisfied: matplotlib>=3.1.2 in /usr/local/lib/python3.10/dist-packages (from descarteslabs[complete]) (3.7.1)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.1.2->descarteslabs[complete]) (1.1.0)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.1.2->descarteslabs[complete]) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.1.2->descarteslabs[complete]) (4.40.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.1.2->descarteslabs[complete]) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.1.2->descarteslabs[complete]) (23.1)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.1.2->descarteslabs[complete]) (3.1.0)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.1.2->descarteslabs[complete]) (2.8.2)
# Requirement already satisfied: click>=3.0 in /usr/local/lib/python3.10/dist-packages (from mercantile>=1.1.3->descarteslabs[complete]) (8.1.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.28.1->descarteslabs[complete]) (2.0.12)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.28.1->descarteslabs[complete]) (3.4)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.28.1->descarteslabs[complete]) (2023.5.7)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.7->matplotlib>=3.1.2->descarteslabs[complete]) (1.16.0)

# %%
import geopandas as gpd

# %%
pip install descartes
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: descartes in /usr/local/lib/python3.10/dist-packages (1.1.0)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (from descartes) (3.7.1)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->descartes) (1.1.0)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib->descartes) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->descartes) (4.40.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->descartes) (1.4.4)
# Requirement already satisfied: numpy>=1.20 in /usr/local/lib/python3.10/dist-packages (from matplotlib->descartes) (1.25.0)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->descartes) (23.1)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->descartes) (9.5.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->descartes) (3.1.0)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib->descartes) (2.8.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.7->matplotlib->descartes) (1.16.0)

# %%
import matplotlib.pyplot as plt

# %%
import geopandas as gpd
from shapely.geometry import Polygon

# %%
import matplotlib.pyplot as plt
from matplotlib.patches import Ellipse

# %%
# Extraer las coordenadas x e y del GeoDataFrame
x_coords = gdf.geometry.x
y_coords = gdf.geometry.y

# Crear un array de coordenadas
coords = np.column_stack((x_coords, y_coords))

# %%
fig, ax = plt.subplots()
SSJ.plot(ax=ax, facecolor='none', edgecolor='black')
puntos_dentro = cents.within(SSJ.geometry.iloc[0])
 # Filtrar puntos dentro del polígono
cents[puntos_dentro].plot(ax=ax, color='red', markersize=5)
plt.show()

# %%
pip install -U numpy
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (1.25.0)

# %% [markdown]
# # **4.BANCO DE INFORMACIÓN DE LA ANH**

# %% [markdown]
# # ***POZOS***

# %%
import pandas as pd

# %%
import geopandas as gpd

# %%
Pozos = gpd.read_file("/content/drive/MyDrive/DATA_ProyectoAG/Datos creados/Pozos/Pozos.shp")

# %%
Pozos.info()
# Out:
# <class 'geopandas.geodataframe.GeoDataFrame'>
# RangeIndex: 263 entries, 0 to 262
# Data columns (total 20 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   FID         263 non-null    int64
#  1   UWI         263 non-null    object
#  2   WELL_NAME   263 non-null    object
#  3   WELL_COUNT  263 non-null    object
#  4   DEPARTAMEN  263 non-null    object
#  5   WELL_COU_1  263 non-null    object
#  6   FIELD_ABRE  259 non-null    object
#  7   GEOLOGIC_P  263 non-null    object
#  8   CONTRATO    263 non-null    object
#  9   WELL_LONGI  263 non-null    float64
#  10  WELL_LATIT  263 non-null    float64
#  11  WELL_CLA_1  179 non-null    object
#  12  WELL_STA_1  259 non-null    object
#  13  WELLTYPE    154 non-null    object
#  14  OPERATOR_W  263 non-null    object
#  15  COMPANY_CO  263 non-null    object
#  16  PLATO       0 non-null      float64
#  17  X           263 non-null    float64
#  18  Y           263 non-null    float64
#  19  geometry    263 non-null    geometry
# dtypes: float64(5), geometry(1), int64(1), object(13)
# memory usage: 41.2+ KB

# %%
Pozos.head(2)
# Out:
#    FID        UWI         WELL_NAME WELL_COUNT DEPARTAMEN  \
# 0  104  ARRE0007P  P-7 ARROYO ARENA   COLOMBIA    BOLIVAR
# 1  173   SANS0002   SAN SEBASTIAN-2   COLOMBIA    CORDOBA
#
#              WELL_COU_1 FIELD_ABRE        GEOLOGIC_P   CONTRATO  WELL_LONGI  \
# 0  EL CARMEN DE BOLIVAR      SAMAN  SINU-SAN JACINTO      SAMAN  -75.160033
# 1            SAN ANTERO       SN 6  SINU-SAN JACINTO  PENDIENTE  -75.773934
#
#    WELL_LATIT WELL_CLA_1             WELL_STA_1  WELLTYPE  \
# 0    9.725972         A3             SIN ESTADO  VERTICAL
# 1    9.300281         A3  TAPONADO Y ABANDONADO  VERTICAL
#
#                               OPERATOR_W                         COMPANY_CO  \
# 0                             HOCOL S.A.                         HOCOL S.A.
# 1  SOCONY VACUUM OIL COMPANY OF COLOMBIA  AGENCIA NACIONAL DE HIDROCARBUROS
#
#    PLATO           X            Y                                   geometry
# 0    NaN  881207.812  1567502.625  POINT Z (881207.812 1567502.625 1640.490)
# 1    NaN  813594.813  1520675.625  POINT Z (813594.813 1520675.625 2194.000)

# %%
import matplotlib.pyplot as plt
fig, ax = plt.subplots(figsize=(12,10))
Pozos.plot(column='FID', ax=ax);

# %%
appending = SSJ.geometry.append(Pozos.geometry)
appending.sample(290)
# Out:
# /usr/local/lib/python3.10/dist-packages/geopandas/geoseries.py:622: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   val = getattr(super(), mtd)(*args, **kwargs)
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-150-4f3e5a549d1b> in <cell line: 2>()
#       1 appending = SSJ.geometry.append(Pozos.geometry)
# ----> 2 appending.sample(290)
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/generic.py in sample(self, n, frac, replace, weights, random_state, axis, ignore_index)
#    5771             weights = sample.preprocess_weights(self, weights, axis)
#    5772
# -> 5773         sampled_indices = sample.sample(obj_len, size, replace, weights, rs)
#    5774         result = self.take(sampled_indices, axis=axis)
#    5775
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/sample.py in sample(obj_len, size, replace, weights, random_state)
#     148             raise ValueError("Invalid weights: weights sum to zero")
#     149
# --> 150     return random_state.choice(obj_len, size=size, replace=replace, p=weights).astype(
#     151         np.intp, copy=False
#     152     )
#
# mtrand.pyx in numpy.random.mtrand.RandomState.choice()
#
# ValueError: Cannot take a larger sample than population when 'replace=False'

# %%
import matplotlib.pyplot as plt

# %%
fig, ax = plt.subplots()
SSJ.plot(ax=ax, facecolor='none', edgecolor='black')
puntos_dentro = Pozos.within(SSJ.geometry.iloc[0])  # Filtrar puntos dentro del polígono
Pozos[puntos_dentro].plot(ax=ax, color='blue', markersize=5)
plt.show()


fig.savefig('/content/drive/MyDrive/DATA_ProyectoAG/Datos creados/Pozos_.png', dpi=300)

# %% [markdown]
# # **Tendencia de los Pozos**

# %%
#Let's plot the distribution of the point pattern
data_scatter = sbn.jointplot(x='WELL_LONGI',
                             y='WELL_LATIT',
                             data=Pozos,
                             s=10.5)

ctx.add_basemap(data_scatter.ax_joint,
                crs='EPSG:4326',
                source=ctx.providers.Stamen.TonerLite)

fig.savefig('/content/drive/MyDrive/DATA_ProyectoAG/Datos creados/TENDENCIApozos.png', dpi=300)

# %% [markdown]
# ### **Ripley's function**

# %%
z1 = gpd.read_file("/content/drive/MyDrive/DATA_ProyectoAG/Datos creados/2DsismicaNN.shp")

# %%
z1.head(2)

# %%
pip install numpy==1.23.5

# %%
f,ax = plt.subplots(
    1,2,figsize=(9,3), gridspec_kw=dict(width_ratios=(6,3))
)

# plot all the simulations with very fine lines
ax[0].plot(f_test.support, f_test.simulations.T, color='k', alpha=.01)
# and show the average of simulations
ax[0].plot(f_test.support, numpy.median(f_test.simulations, axis=0), color='cyan',
         label='median simulation')


# and the observed pattern's F function
ax[0].plot(f_test.support, f_test.statistic, label = 'observed', color='red')

# clean up labels and axes
ax[0].set_xlabel('distance')
ax[0].set_ylabel('% of nearest point in pattern\ndistances shorter')
ax[0].legend()
ax[0].set_xlim(0,2000)
ax[0].set_title(r"Ripley's $F(d)$ function")

# plot the pattern itself on the next frame
ax[1].scatter(*coordinates.T)

# and clean up labels and axes there, too
ax[1].set_xticks([])
ax[1].set_yticks([])
ax[1].set_xticklabels([])
ax[1].set_yticklabels([])
ax[1].set_title('Pattern')
f.tight_layout()
plt.show()

# %% [markdown]
# # **Kernel Density Estimation_Pozos**

# %%
import matplotlib.pyplot as plt

# %%
import seaborn as sbn

# %%
import geopandas as gpd

# %%
import contextily as ctx

# %%
limites=SSJ.geometry.total_bounds

# %%
#gdf = gpd.read_file(.shp')'/content/drive/MyDrive/DATA_ProyectoAG/Datos creados/Emisiones SSJ

# %%
#bounds = gdf.total_bounds

# %%
import geopandas as gpd
from pyproj import Transformer

# Crear instancia del transformador de coordenadas
transformer = Transformer.from_crs('EPSG:3116', 'EPSG:4326')

# Aplicar la transformación a las geometrías
Pozos['geometry'] = Pozos['geometry'].to_crs('EPSG:4326')

# Guardar el archivo shapefile transformado
#df.to_file('Pozos_transformed.shp')

# %%
print(Pozos.crs)
# Out:
# EPSG:4326

# %%
# Set up figure and axis
f, ax = plt.subplots(1, figsize=(9, 9))
# Generate and add KDE with a shading of 50 gradients
# coloured contours, 75% of transparency,
# and the reverse viridis colormap
sbn.kdeplot(
    x=Pozos['X'],
    y=Pozos['Y'],
    n_levels=30,
    fill=True,
    alpha=0.55,
    cmap='viridis_r'
)
# Add basemap
ctx.add_basemap(ax=ax,crs=Sismica.crs.to_string(),
    source=ctx.providers.CartoDB.Positron, zoom=10
)
# Remove axes
ax.set_axis_off()


plt.savefig('/content/drive/MyDrive/DATA_ProyectoAG/Datos creados/Pozos_kde.png')

# %%
# !pip install datashader
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting datashader
#   Downloading datashader-0.15.0-py2.py3-none-any.whl (18.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 18.3/18.3 MB 44.9 MB/s eta 0:00:00
# Requirement already satisfied: colorcet in /usr/local/lib/python3.10/dist-packages (from datashader) (3.0.1)
# Requirement already satisfied: dask in /usr/local/lib/python3.10/dist-packages (from datashader) (2022.12.1)
# Collecting datashape (from datashader)
#   Downloading datashape-0.5.2.tar.gz (76 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 76.5/76.5 kB 8.3 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: numba in /usr/local/lib/python3.10/dist-packages (from datashader) (0.56.4)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from datashader) (1.23.5)
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from datashader) (1.5.3)
# Requirement already satisfied: param in /usr/local/lib/python3.10/dist-packages (from datashader) (1.13.0)
# Requirement already satisfied: pillow in /usr/local/lib/python3.10/dist-packages (from datashader) (9.5.0)
# Requirement already satisfied: pyct in /usr/local/lib/python3.10/dist-packages (from datashader) (0.5.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from datashader) (2.31.0)
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/dist-packages (from datashader) (1.10.1)
# Requirement already satisfied: toolz in /usr/local/lib/python3.10/dist-packages (from datashader) (0.12.0)
# Requirement already satisfied: xarray in /usr/local/lib/python3.10/dist-packages (from datashader) (2022.12.0)
# Requirement already satisfied: click>=7.0 in /usr/local/lib/python3.10/dist-packages (from dask->datashader) (8.1.3)
# Requirement already satisfied: cloudpickle>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from dask->datashader) (2.2.1)
# Requirement already satisfied: fsspec>=0.6.0 in /usr/local/lib/python3.10/dist-packages (from dask->datashader) (2023.4.0)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from dask->datashader) (23.1)
# Requirement already satisfied: partd>=0.3.10 in /usr/local/lib/python3.10/dist-packages (from dask->datashader) (1.4.0)
# Requirement already satisfied: pyyaml>=5.3.1 in /usr/local/lib/python3.10/dist-packages (from dask->datashader) (6.0)
# Requirement already satisfied: multipledispatch>=0.4.7 in /usr/local/lib/python3.10/dist-packages (from datashape->datashader) (0.6.0)
# Requirement already satisfied: python-dateutil in /usr/local/lib/python3.10/dist-packages (from datashape->datashader) (2.8.2)
# Requirement already satisfied: llvmlite<0.40,>=0.39.0dev0 in /usr/local/lib/python3.10/dist-packages (from numba->datashader) (0.39.1)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from numba->datashader) (67.7.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->datashader) (2022.7.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->datashader) (2.0.12)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->datashader) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->datashader) (1.26.15)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->datashader) (2022.12.7)
# Requirement already satisfied: six in /usr/local/lib/python3.10/dist-packages (from multipledispatch>=0.4.7->datashape->datashader) (1.16.0)
# Requirement already satisfied: locket in /usr/local/lib/python3.10/dist-packages (from partd>=0.3.10->dask->datashader) (1.0.0)
# Building wheels for collected packages: datashape
#   Building wheel for datashape (setup.py) ... done
#   Created wheel for datashape: filename=datashape-0.5.2-py3-none-any.whl size=59421 sha256=58a5c67d07350af3c7d89655f3b7bed7db4a179d8e0da7795566b254814d89b8
#   Stored in directory: /root/.cache/pip/wheels/35/c6/63/a3c12ecc9fdea10a593271de5c56481b427ad4049b90a176e1
# Successfully built datashape
# Installing collected packages: datashape, datashader
# Successfully installed datashader-0.15.0 datashape-0.5.2

# %%
pip install numpy==1.23.5
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: numpy==1.23.5 in /usr/local/lib/python3.10/dist-packages (1.23.5)

# %%
import datashader
cvs = datashader.Canvas(plot_width=60,plot_height=60)
grid = cvs.points(Pozos, x="X", y="Y")
# Out:
# ---------------------------------------------------------------------------
# SystemError                               Traceback (most recent call last)
# <ipython-input-126-7301977ccafc> in <cell line: 1>()
# ----> 1 import datashader
#       2 cvs = datashader.Canvas(plot_width=60,plot_height=60)
#       3 grid = cvs.points(Pozos, x="X", y="Y")
#
# /usr/local/lib/python3.10/dist-packages/datashader/__init__.py in <module>
#       6 __version__ = str(param.version.Version(fpath=__file__, archive_commit="$Format:%h$",reponame="datashader"))
#       7
# ----> 8 from .core import Canvas                                 # noqa (API import)
#       9 from .reductions import *                                # noqa (API import)
#      10 from .glyphs import Point                                # noqa (API import)
#
# /usr/local/lib/python3.10/dist-packages/datashader/core.py in <module>
#      12 from collections import OrderedDict
#      13
# ---> 14 from .utils import Dispatcher, ngjit, calc_res, calc_bbox, orient_array, \
#      15     dshape_from_xarray_dataset
#      16 from .utils import get_indices, dshape_from_pandas, dshape_from_dask
#
# /usr/local/lib/python3.10/dist-packages/datashader/utils.py in <module>
#       6 from inspect import getmro
#       7
# ----> 8 import numba as nb
#       9 import numpy as np
#      10 import pandas as pd
#
# /usr/local/lib/python3.10/dist-packages/numba/__init__.py in <module>
#      40
#      41 # Re-export vectorize decorators and the thread layer querying function
# ---> 42 from numba.np.ufunc import (vectorize, guvectorize, threading_layer,
#      43                             get_num_threads, set_num_threads,
#      44                             set_parallel_chunksize, get_parallel_chunksize,
#
# /usr/local/lib/python3.10/dist-packages/numba/np/ufunc/__init__.py in <module>
#       1 # -*- coding: utf-8 -*-
#       2
# ----> 3 from numba.np.ufunc.decorators import Vectorize, GUVectorize, vectorize, guvectorize
#       4 from numba.np.ufunc._internal import PyUFunc_None, PyUFunc_Zero, PyUFunc_One
#       5 from numba.np.ufunc import _internal, array_exprs
#
# /usr/local/lib/python3.10/dist-packages/numba/np/ufunc/decorators.py in <module>
#       1 import inspect
#       2
# ----> 3 from numba.np.ufunc import _internal
#       4 from numba.np.ufunc.parallel import ParallelUFuncBuilder, ParallelGUFuncBuilder
#       5
#
# SystemError: initialization of _internal failed without raising an exception

# %% [markdown]
# ### ***SISMICA 2D***

# %%
Sismica = gpd.read_file("/content/drive/MyDrive/DATA_ProyectoAG/Datos creados/Puntos_lineas2D.shp")

# %%
Sismica.info()
# Out:
# <class 'geopandas.geodataframe.GeoDataFrame'>
# RangeIndex: 2085 entries, 0 to 2084
# Data columns (total 5 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   org_fid   2085 non-null   int64
#  1   distance  2085 non-null   float64
#  2   X         2085 non-null   float64
#  3   Y         2085 non-null   float64
#  4   geometry  2085 non-null   geometry
# dtypes: float64(3), geometry(1), int64(1)
# memory usage: 81.6 KB

# %%
Sismica.head(2)
# Out:
#    org_fid  distance           X            Y                        geometry
# 0        1       0.0  771591.290  1470255.942  POINT (771591.290 1470255.942)
# 1        1    8000.0  779326.039  1468608.607  POINT (779326.039 1468608.607)

# %%
import matplotlib.pyplot as plt
SSJ.plot(ax=ax, facecolor='none', edgecolor='black')
fig, ax = plt.subplots(figsize=(12,10))
Sismica.plot(column='org_fid', ax=ax);
plt.savefig('/content/drive/MyDrive/DATA_ProyectoAG/Datos creados/Puntos_lineas2Ddistribución.png')

# %%
fig, ax = plt.subplots()
SSJ.plot(ax=ax, facecolor='none', edgecolor='black')
puntos_dentro = Sismica.within(SSJ.geometry.iloc[0])  # Filtrar puntos dentro del polígono
Sismica[puntos_dentro].plot(ax=ax, color='blue', markersize=5)
plt.show()


fig.savefig('/content/drive/MyDrive/DATA_ProyectoAG/Datos creados/linea2Ds.png', dpi=300)

# %% [markdown]
# ## **Tendencia de las lineas sismicas 2D**

# %%
#Let's plot the distribution of the point pattern
data_scatter = sbn.jointplot(x='X',
                             y='Y',
                             data=Sismica,
                             s=10.5)

ctx.add_basemap(data_scatter.ax_joint,
                crs='EPSG:3116',
                source=ctx.providers.Stamen.TonerLite)

fig.savefig('/content/drive/MyDrive/DATA_ProyectoAG/Datos creados/distribucionsimica2d.png', dpi=300)

# %% [markdown]
# # **Kernel density estimation_lineas sismicas 2D**

# %%
# Set up figure and axis
f, ax = plt.subplots(1, figsize=(9, 9))
# Generate and add KDE with a shading of 50 gradients
# coloured contours, 75% of transparency,
# and the reverse viridis colormap
sbn.kdeplot(
    x=Sismica['X'],
    y=Sismica['Y'],
    n_levels=30,
    shade=True,
    alpha=0.55,
    cmap='viridis_r'
)
# Add basemap
ctx.add_basemap(ax=ax,crs=Sismica.crs.to_string(),
    source=ctx.providers.CartoDB.Positron
)
# Remove axes
ax.set_axis_off()

plt.savefig('/content/drive/MyDrive/DATA_ProyectoAG/Datos creados/Lineas2D_kde.png')
# Out:
# <ipython-input-88-205b48b38fb6>:6: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sbn.kdeplot(

# %% [markdown]
# ### ***SISMICA 3D***

# %%
Cubosismico = gpd.read_file("/content/drive/MyDrive/DATA_ProyectoAG/Datos creados/SISMICA3D.shp")

# %%
Cubosismico.info()
# Out:
# <class 'geopandas.geodataframe.GeoDataFrame'>
# RangeIndex: 1 entries, 0 to 0
# Data columns (total 15 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   FID         1 non-null      int64
#  1   CONTRATO    1 non-null      object
#  2   AREA_KM2    1 non-null      float64
#  3   NOMBRE      1 non-null      object
#  4   COMPANY_OP  1 non-null      object
#  5   CUENCA_GEO  1 non-null      object
#  6   COMP_SERVI  1 non-null      object
#  7   FECHA_ADQU  1 non-null      object
#  8   XMIN        1 non-null      float64
#  9   XMAX        1 non-null      float64
#  10  YMIN        1 non-null      float64
#  11  YMAX        1 non-null      float64
#  12  SHAPE_Leng  1 non-null      float64
#  13  SHAPE_Area  1 non-null      float64
#  14  geometry    1 non-null      geometry
# dtypes: float64(7), geometry(1), int64(1), object(6)
# memory usage: 248.0+ bytes

# %%
Cubosismico.head(2)
# Out:
#    FID CONTRATO    AREA_KM2         NOMBRE                 COMPANY_OP  \
# 0   80  SSJN-01  299.839584  SSJN1 3D-2010  LEWIS ENERGY COLOMBIA INC
#
#          CUENCA_GEO       COMP_SERVI  FECHA_ADQU       XMIN       XMAX  \
# 0  SINU-SAN JACINTO  SISMOPETROL SAS  1900-01-01 -75.026992 -74.807267
#
#         YMIN       YMAX    SHAPE_Leng  SHAPE_Area  \
# 0  10.535074  10.726609  80345.005075    0.024769
#
#                                             geometry
# 0  POLYGON ((908059.791 1674776.693, 908361.417 1...

# %%
import matplotlib.pyplot as plt
fig, ax = plt.subplots(figsize=(12,10))
Cubosismico.plot(column='FID', ax=ax);

# %%
fig, ax = plt.subplots()
SSJ.plot(ax=ax, facecolor='none', edgecolor='black')
puntos_dentro = Cubosismico.within(SSJ.geometry.iloc[0])  # Filtrar puntos dentro del polígono
Cubosismico[puntos_dentro].plot(ax=ax, color='purple', markersize=5)
plt.show()


fig.savefig('/content/drive/MyDrive/DATA_ProyectoAG/Datos creados/cubosiss.png', dpi=300)

# %% [markdown]
# ## ***VOLCANES***

# %%
VOLCANES= gpd.read_file("/content/drive/MyDrive/DATA_ProyectoAG/Datos creados/Volcan.shp")

# %%
VOLCANES.info()
# Out:
# <class 'geopandas.geodataframe.GeoDataFrame'>
# RangeIndex: 8 entries, 0 to 7
# Data columns (total 4 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   id        8 non-null      int64
#  1   X         8 non-null      int64
#  2   Y         8 non-null      int64
#  3   geometry  8 non-null      geometry
# dtypes: geometry(1), int64(3)
# memory usage: 384.0 bytes

# %%
VOLCANES.head(2)
# Out:
#    id       X        Y                        geometry
# 0   1  871162  1685473  POINT (871162.292 1685472.869)
# 1   2  872581  1679998  POINT (872581.220 1679997.739)

# %%
import matplotlib.pyplot as plt
fig, ax = plt.subplots(figsize=(12,10))
VOLCANES.plot(column='geometry', ax=ax);

# %%
fig, ax = plt.subplots()
SSJ.plot(ax=ax, facecolor='none', edgecolor='black')
puntos_dentro = VOLCANES.within(SSJ.geometry.iloc[0])  # Filtrar puntos dentro del polígono
VOLCANES[puntos_dentro].plot(ax=ax, color='blue', markersize=5)
plt.show()


fig.savefig('/content/drive/MyDrive/DATA_ProyectoAG/Datos creados/VOLCANES.png', dpi=300)

# %%
#Let's plot the distribution of the point pattern
data_scatter = sbn.jointplot(x='X',
                             y='Y',
                             data=VOLCANES,
                             s=10.5)

ctx.add_basemap(data_scatter.ax_joint,
                crs='EPSG:3116',
                source=ctx.providers.Stamen.TonerLite)

fig.savefig('/content/drive/MyDrive/DATA_ProyectoAG/Datos creados/distribucionsimica2d.png', dpi=300)

# %%
# Set up figure and axis
f, ax = plt.subplots(1, figsize=(9, 9))
# Generate and add KDE with a shading of 50 gradients
# coloured contours, 75% of transparency,
# and the reverse viridis colormap
sbn.kdeplot(
    x=VOLCANES['X'],
    y=VOLCANES['Y'],
    n_levels=30,
    shade=True,
    alpha=0.55,
    cmap='viridis_r'
)
# Add basemap
ctx.add_basemap(ax=ax,crs=VOLCANES.crs.to_string(),
    source=ctx.providers.CartoDB.Positron
)

# Remove axes
ax.set_axis_off()

plt.savefig('/content/drive/MyDrive/DATA_ProyectoAG/Datos creados/VOLCANES_kde.png')
# Out:
# <ipython-input-100-b5702154194f>:6: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sbn.kdeplot(

# %% [markdown]
# ## **COORDENADAS DEL PROYECTO**

# %%
print(Pozos.crs)
# Out:
# EPSG:3116

# %%
print(Sismica.crs)
# Out:
# EPSG:3116

# %%
print(Cubosismico.crs)
# Out:
# EPSG:3116

# %%
print(VOLCANES.crs)
# Out:
# EPSG:3116

# %%
print(Ciudades.crs)
# Out:
# EPSG:3116

# %%
f, axs = plt.subplots(1, 2, figsize=(14, 6))
Pozos.plot(ax=axs[0])
Sismica.plot(ax=axs[1]);

# %%
fig, ax = plt.subplots(figsize=(12,10))
appending.plot(ax=ax)
Cubosismico.plot(ax=ax, color='purple')
Pozos.plot(ax=ax, color='red')
Sismica.plot(ax=ax, color='black')
fig.savefig('/content/drive/MyDrive/DATA_ProyectoAG/Datos creados/Datatotal.png', dpi=300)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-151-11705b0edfc6> in <cell line: 3>()
#       1 fig, ax = plt.subplots(figsize=(12,10))
#       2 appending.plot(ax=ax)
# ----> 3 Cubosismico.plot(ax=ax, color='purple')
#       4 Pozos.plot(ax=ax, color='red')
#       5 Sismica.plot(ax=ax, color='black')
#
# NameError: name 'Cubosismico' is not defined
